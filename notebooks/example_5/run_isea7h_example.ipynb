# %% [markdown]
# # Example 5: Mesh Remapping
#
# This notebook demonstrates how to use uraster to remap raster data to an unstructured mesh.

# %%
import os
from uraster.classes.uraster import uraster
from uraster.utility import get_example_paths
print("Downloading example 5 input data...")
paths = get_example_paths(example_number=5)
sFolder_input = paths['input']
print(f"Input data cached at: {sFolder_input}")

sFolder_output = os.path.join("data", "example_5", "output")
os.makedirs(sFolder_output, exist_ok=True)
print(f"Output directory: {sFolder_output}")
# Out:
# Downloading file 'example_5.zip' from 'https://github.com/changliao1025/uraster_data/releases/download/v0.1.5/example_5.zip' to '/Users/liao313/Library/Caches/uraster'.
# Downloading example 5 input data...
# Downloading example 5 data...
# Source: https://github.com/changliao1025/uraster_data/releases/download/v0.1.5/example_5.zip
# 100%|█████████████████████████████████████| 1.63G/1.63G [00:00<00:00, 2.15TB/s]
# Unzipping contents of '/Users/liao313/Library/Caches/uraster/example_5.zip' to '/Users/liao313/Library/Caches/uraster/example_5.zip.unzip'
#   Organized files into input directory
# ✓ Downloaded and extracted: example_5.zip
#   Location: /Users/liao313/Library/Caches/uraster/example_5.zip.unzip/example_5
#   Files extracted: 5
# Input data cached at: /Users/liao313/Library/Caches/uraster/example_5.zip.unzip/example_5/input
# Output directory: data/example_5/output

# %%
sFilename_source_mesh = os.path.join(sFolder_input, "isea7h_bbox_res5.geojson")
sFilename_target_mesh = os.path.join(sFolder_output, "uraster.geojson")
sFilename_mesh_png = os.path.join(sFolder_output, "mesh.jpg")
sFilename_raster_png = os.path.join(sFolder_output, "raster.png")
sFilename_variable_png = os.path.join(sFolder_output, "uraster.png")
sFilename_variable_animation = os.path.join(sFolder_output, "uraster_animation.mp4")

# %% [markdown]
# ## Configure and Run Remapping

# %%
aConfig = dict()
aConfig["sFilename_source_mesh"] = sFilename_source_mesh
aFilename_source_raster = []
sFilename_raster0 = os.path.join(sFolder_input, "Hansen_GFC-2019-v1.7_treecover2000_40N_090W.tif")
sFilename_raster1 = os.path.join(sFolder_input, "Hansen_GFC-2019-v1.7_treecover2000_50N_090W.tif")
sFilename_raster2 = os.path.join(sFolder_input, "Hansen_GFC-2019-v1.7_treecover2000_40N_100W.tif")
sFilename_raster3 = os.path.join(sFolder_input, "Hansen_GFC-2019-v1.7_treecover2000_50N_100W.tif")
aFilename_source_raster.append(sFilename_raster0)
aFilename_source_raster.append(sFilename_raster1)
aFilename_source_raster.append(sFilename_raster2)
aFilename_source_raster.append(sFilename_raster3)
aConfig["aFilename_source_raster"] = aFilename_source_raster
aConfig["sFilename_target_mesh"] = sFilename_target_mesh
pRaster = uraster(aConfig)

# %%
pRaster.setup()
# Out:
# 2026-01-20 15:04:11,618 - uraster - INFO - Found field 'cellid' but not integer type - will regenerate with sequential integer IDs
# 2026-01-20 15:04:11,619 - uraster - INFO - Creating intermediate file with sequential integer field 'cellid'...
# 2026-01-20 15:04:11,847 - uraster - INFO - Added field 'cellid' to 508 features
# 2026-01-20 15:04:11,848 - uraster - INFO - Successfully created intermediate file: /Users/liao313/Library/Caches/uraster/example_5.zip.unzip/example_5/input/isea7h_bbox_res5_with_cellid.geojson
# 2026-01-20 15:04:11,848 - uraster - INFO - Updated source mesh path to: /Users/liao313/Library/Caches/uraster/example_5.zip.unzip/example_5/input/isea7h_bbox_res5_with_cellid.geojson
# True

# %%
pRaster.report_inputs()
# Out:
# ============================================================
# Input Raster Information (4 file(s)):
# ============================================================
#
# [1] /Users/liao313/Library/Caches/uraster/example_5.zip.unzip/example_5/input/Hansen_GFC-2019-v1.7_treecover2000_40N_090W.tif
# Filename: /Users/liao313/Library/Caches/uraster/example_5.zip.unzip/example_5/input/Hansen_GFC-2019-v1.7_treecover2000_40N_090W.tif
# Width: 40000
# Height: 40000
# Band Count: 1
# Data Type: Byte
# NoData Value: None
# CRS: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Spatial Reference WKT: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Affine Transform: (-90.0, 0.00025, 0.0, 40.0, 0.0, -0.00025)
# Extent: (-90.0, 30.0, -80.0, 40.0)
# WGS84 Extent: (-90.0, 30.0, -80.0, 40.0)
#
# [2] /Users/liao313/Library/Caches/uraster/example_5.zip.unzip/example_5/input/Hansen_GFC-2019-v1.7_treecover2000_50N_090W.tif
# Filename: /Users/liao313/Library/Caches/uraster/example_5.zip.unzip/example_5/input/Hansen_GFC-2019-v1.7_treecover2000_50N_090W.tif
# Width: 40000
# Height: 40000
# Band Count: 1
# Data Type: Byte
# NoData Value: None
# CRS: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Spatial Reference WKT: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Affine Transform: (-90.0, 0.00025, 0.0, 50.0, 0.0, -0.00025)
# Extent: (-90.0, 40.0, -80.0, 50.0)
# WGS84 Extent: (-90.0, 40.0, -80.0, 50.0)
#
# [3] /Users/liao313/Library/Caches/uraster/example_5.zip.unzip/example_5/input/Hansen_GFC-2019-v1.7_treecover2000_40N_100W.tif
# Filename: /Users/liao313/Library/Caches/uraster/example_5.zip.unzip/example_5/input/Hansen_GFC-2019-v1.7_treecover2000_40N_100W.tif
# Width: 40000
# Height: 40000
# Band Count: 1
# Data Type: Byte
# NoData Value: None
# CRS: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Spatial Reference WKT: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Affine Transform: (-100.0, 0.00025, 0.0, 40.0, 0.0, -0.00025)
# Extent: (-100.0, 30.0, -90.0, 40.0)
# WGS84 Extent: (-100.0, 30.0, -90.0, 40.0)
#
# [4] /Users/liao313/Library/Caches/uraster/example_5.zip.unzip/example_5/input/Hansen_GFC-2019-v1.7_treecover2000_50N_100W.tif
# Filename: /Users/liao313/Library/Caches/uraster/example_5.zip.unzip/example_5/input/Hansen_GFC-2019-v1.7_treecover2000_50N_100W.tif
# Width: 40000
# Height: 40000
# Band Count: 1
# Data Type: Byte
# NoData Value: None
# CRS: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Spatial Reference WKT: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Affine Transform: (-100.0, 0.00025, 0.0, 50.0, 0.0, -0.00025)
# Extent: (-100.0, 40.0, -90.0, 50.0)
# WGS84 Extent: (-100.0, 40.0, -90.0, 50.0)
#
# ============================================================
# Mesh Topology Information:
# ============================================================
# Number of mesh cells: 507
# Cell longitude range: -100.384 to -78.640
# Cell latitude range: 29.493 to 50.468
# Maximum vertices per cell: 91
# Total unique vertices: 25564
# Connectivity matrix shape: (507, 91)
#
# Cell Area Statistics:
#   Min area: 2536695371.933842
#   Max area: 149077959947.213745
#   Mean area: 10229728642.179413
#   Area range ratio: 58.77x
# ============================================================

# %% [markdown]
# ## Visualize Source Mesh

# %%
dLongitude_focus_in = (pRaster.aExtent_rasters[0] + pRaster.aExtent_rasters[2]) / 2
dLatitude_focus_in = (pRaster.aExtent_rasters[1] + pRaster.aExtent_rasters[3]) / 2
pRaster.visualize_source_mesh(
    #sFilename_out=sFilename_mesh_png,
    dLongitude_focus_in=dLongitude_focus_in,
    dLatitude_focus_in=dLatitude_focus_in
)
# Out:
# Widget(value='<iframe src="http://localhost:57401/index.html?ui=P_0x1d91b13a0_0&reconnect=auto" class="pyvista…
# True

# %% [markdown]
# ## Run Remapping

# %%
pRaster.run_remap(iFlag_weighted_average_in=False)
# Out:
# 2026-01-20 15:04:23,145 - extract - INFO - run_remap: Starting main feature processing loop...
# 2026-01-20 15:04:23,146 - extract - INFO - Preparing to process 507 features (parallel threshold=10000)
# 2026-01-20 15:04:23,147 - extract - INFO - Feature count (507) <= threshold (10000); using serial processing
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pRaster.run_remap(iFlag_weighted_average_in=False)
#
# File ~/workspace/python/uraster/uraster/classes/uraster.py:1185, in uraster.run_remap(self, sFilename_target_mesh_out, sFilename_source_mesh_in, aFilename_source_raster_in, iFlag_stat_in, iFlag_weighted_average_in, iFlag_remap_method_in, iFlag_save_clipped_raster_in, sFolder_raster_out_in, iFlag_discrete_in, iFlag_verbose_in)
#    1173     return intersect.run_remap(
#    1174         sFilename_target_mesh,
#    1175         sFilename_source_mesh,
#    (...)   1181         iFlag_verbose_in=iFlag_verbose_in,
#    1182     )
#    1184 else:
# -> 1185     return extract.run_remap(
#    1186         sFilename_target_mesh,
#    1187         sFilename_source_mesh,
#    1188         aFilename_source_raster,
#    1189         self.dArea_min,
#    1190         iFlag_remap_method_in=iFlag_remap_method_in,
#    1191         iFlag_discrete_in=iFlag_discrete_in,
#    1192         iFlag_stat_in=iFlag_stat_in,
#    1193         iFlag_save_clipped_raster_in=iFlag_save_clipped_raster_in,
#    1194         sFolder_raster_out_in=sFolder_raster_out_in,
#    1195         iFlag_verbose_in=iFlag_verbose_in,
#    1196         sField_unique_id=self.sField_unique_id,
#    1197     )
#
# File ~/workspace/python/uraster/uraster/operation/extract.py:1440, in run_remap(sFilename_target_mesh, sFilename_source_mesh, aFilename_source_raster, dArea_min, iFlag_remap_method_in, iFlag_stat_in, iFlag_save_clipped_raster_in, sFolder_raster_out_in, iFlag_discrete_in, iFlag_verbose_in, iFeature_parallel_threshold, sField_unique_id)
#    1436 logger.info(
#    1437     f"Feature count ({n_features}) <= threshold ({iFeature_parallel_threshold}); using serial processing"
#    1438 )
#    1439 for task in tasks:
# -> 1440     feature_idx, cellid, success, payload = _process_task(task)
#    1441     if not success:
#    1442         failed_features.append(
#    1443             {"feature_id": cellid, "error": payload, "envelope": None}
#    1444         )
#
# File ~/workspace/python/uraster/uraster/operation/extract.py:965, in _process_task(args)
#     962     logger.debug(f"Processing {sGeometry_type} geometry for feature {cellid}")
#     964 if sGeometry_type == "POLYGON":
# --> 965     return _process_single_polygon(
#     966         feature_idx,
#     967         cellid,
#     968         wkt,
#     969         aFilename_source_raster,
#     970         gdal_warp_options_base,
#     971         dMissing_value,
#     972         iFlag_discrete_in,
#     973         iFlag_verbose_in,
#     974         aUnique_value,
#     975     )
#     977 elif sGeometry_type == "MULTIPOLYGON":
#     978     merged_data, merged_transform = _process_multipolygon_idl(
#     979         feature_idx,
#     980         cellid,
#    (...)    987         aUnique_value,
#     988     )
#
# File ~/workspace/python/uraster/uraster/operation/extract.py:288, in _process_single_polygon(iFeature_idx, iCellid, sWkt, aFilename_source_raster, gdal_warp_options_base, dMissing_value, iFlag_discrete_in, iFlag_verbose_in, aUnique_value)
#     286 pWrapOption = gdal.WarpOptions(**gdal_warp_options)
#     287 gdal.PushErrorHandler(custom_error_handler)
# --> 288 pDataset_warp = gdal.Warp("", aFilename_source_raster, options=pWrapOption)
#     289 gdal.PopErrorHandler()
#     291 if pDataset_warp is None:
#
# File ~/miniconda3/envs/geovista/lib/python3.12/site-packages/osgeo/gdal.py:1116, in Warp(destNameOrDestDS, srcDSOrSrcDSTab, **kwargs)
#    1113     srcDSTab = [srcDSOrSrcDSTab]
#    1115 if isinstance(destNameOrDestDS, (str, os.PathLike)):
# -> 1116     return wrapper_GDALWarpDestName(destNameOrDestDS, srcDSTab, opts, callback, callback_data)
#    1117 else:
#    1118     return wrapper_GDALWarpDestDS(destNameOrDestDS, srcDSTab, opts, callback, callback_data)
#
# File ~/miniconda3/envs/geovista/lib/python3.12/site-packages/osgeo/gdal.py:6110, in wrapper_GDALWarpDestName(*args)
#    6108 def wrapper_GDALWarpDestName(*args):
#    6109     r"""wrapper_GDALWarpDestName(char const * dest, int object_list_count, GDALWarpAppOptions warpAppOptions, GDALProgressFunc callback=0, void * callback_data=None) -> Dataset"""
# -> 6110     return _gdal.wrapper_GDALWarpDestName(*args)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
pRaster.report_outputs()

# %% [markdown]
# ## Visualize Results

# %%
sColormap = "terrain"
pRaster.visualize_target_mesh(
    #sFilename_out=sFilename_variable_png,
    sColormap=sColormap,
    dLongitude_focus_in=dLongitude_focus_in,
    dLatitude_focus_in=dLatitude_focus_in
)

# %% [markdown]
# ## Optional: Create Animation
#
# Uncomment and run the following cell to create an animation (may take some time).

# %% [markdown]
# ## Cleanup

# %%
pRaster.cleanup()
print("done")
