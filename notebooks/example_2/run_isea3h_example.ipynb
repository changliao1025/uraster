# %% [markdown]
# # Example 2: Mesh Remapping
#
# This notebook demonstrates how to use uraster to remap raster data to an unstructured mesh.

# %%
import os
from uraster.classes.uraster import uraster
# Download input data using Pooch (downloads to system cache)
from uraster.utility import get_example_paths

print("Downloading example 2 input data...")
paths = get_example_paths(example_number=2)
sFolder_input = paths['input']
print(f"Input data cached at: {sFolder_input}")

# Set up output directory relative to current working directory
sFolder_output = os.path.join("data", "example_2", "output")
os.makedirs(sFolder_output, exist_ok=True)
print(f"Output directory: {sFolder_output}")
# Out:
# Downloading file 'example_2.zip' from 'https://github.com/changliao1025/uraster_data/releases/download/v0.1.5/example_2.zip' to '/Users/liao313/Library/Caches/uraster'.
# Downloading example 2 input data...
# Downloading example 2 data...
# Source: https://github.com/changliao1025/uraster_data/releases/download/v0.1.5/example_2.zip
# 100%|█████████████████████████████████████| 6.76M/6.76M [00:00<00:00, 7.70GB/s]
# Unzipping contents of '/Users/liao313/Library/Caches/uraster/example_2.zip' to '/Users/liao313/Library/Caches/uraster/example_2.zip.unzip'
#   Organized files into input directory
# ✓ Downloaded and extracted: example_2.zip
#   Location: /Users/liao313/Library/Caches/uraster/example_2.zip.unzip/example_2
#   Files extracted: 2
# Input data cached at: /Users/liao313/Library/Caches/uraster/example_2.zip.unzip/example_2/input
# Output directory: data/example_2/output

# %%
# Input file paths (from Pooch cache)
sFilename_source_mesh = os.path.join(
    sFolder_input, "isea3h_bbox_res15.geojson"
)  # use the L10-100 test mesh
sFilename_raster = os.path.join(sFolder_input, "WSF2015_v2_-80_42.tif")

# Output file paths (relative to working directory)
sFilename_target_mesh = os.path.join(sFolder_output, "uraster.geojson")
sFilename_mesh_png = os.path.join(sFolder_output, "mesh.jpg")
sFilename_raster_png = os.path.join(sFolder_output, "raster.png")
sFilename_variable_png = os.path.join(sFolder_output, "uraster.png")
sFilename_variable_animation = os.path.join(sFolder_output, "uraster_animation.mp4")

# %% [markdown]
# ## Configure and Run Remapping
#
# Set up the configuration and run the remapping process.

# %%
aConfig = dict()
aConfig["sFilename_source_mesh"] = (
    sFilename_source_mesh  # use the L10-100 test mesh
)
aFilename_source_raster = []

aFilename_source_raster.append(sFilename_raster)  # dem from hydros
aConfig["aFilename_source_raster"] = aFilename_source_raster
aConfig["sFilename_target_mesh"] = sFilename_target_mesh
aConfig["iFlag_discrete"] = 1
pRaster = uraster(aConfig)

# %%
pRaster.setup()
# Out:
# 2026-01-20 14:43:25,403 - uraster - INFO - Found field 'cellid' but not integer type - will regenerate with sequential integer IDs
# 2026-01-20 14:43:25,404 - uraster - INFO - Creating intermediate file with sequential integer field 'cellid'...
# 2026-01-20 14:43:25,702 - uraster - INFO - Added field 'cellid' to 1317 features
# 2026-01-20 14:43:25,703 - uraster - INFO - Successfully created intermediate file: /Users/liao313/Library/Caches/uraster/example_2.zip.unzip/example_2/input/isea3h_bbox_res15_with_cellid.geojson
# 2026-01-20 14:43:25,704 - uraster - INFO - Updated source mesh path to: /Users/liao313/Library/Caches/uraster/example_2.zip.unzip/example_2/input/isea3h_bbox_res15_with_cellid.geojson
# True

# %%
pRaster.report_inputs()
# Out:
# ============================================================
# Input Raster Information (1 file(s)):
# ============================================================
#
# [1] /Users/liao313/Library/Caches/uraster/example_2.zip.unzip/example_2/input/WSF2015_v2_-80_42.tif
# Filename: /Users/liao313/Library/Caches/uraster/example_2.zip.unzip/example_2/input/WSF2015_v2_-80_42.tif
# Width: 22488
# Height: 22488
# Band Count: 1
# Data Type: Byte
# NoData Value: None
# CRS: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Spatial Reference WKT: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Affine Transform: (-80.0100677476166, 8.983152841195215e-05, 0.0, 44.01008273652677, 0.0, -8.983152841195215e-05)
# Extent: (-80.0100677476166, 41.98995132559879, -77.98993633668863, 44.01008273652677)
# WGS84 Extent: (-80.0100677476166, 41.98995132559879, -77.98993633668863, 44.01008273652677)
#
# ============================================================
# Mesh Topology Information:
# ============================================================
# Number of mesh cells: 1316
# Cell longitude range: -80.116 to -77.785
# Cell latitude range: 41.790 to 44.110
# Maximum vertices per cell: 49
# Total unique vertices: 34051
# Connectivity matrix shape: (1316, 49)
#
# Cell Area Statistics:
#   Min area: 3555128.360417
#   Max area: 2593129402.200589
#   Mean area: 40959064.563719
#   Area range ratio: 729.41x
# ============================================================

# %% [markdown]
# ## Visualize Source Mesh

# %%
# visualize source mesh at the Idaho Falls area
dLongitude_focus_in = (pRaster.aExtent_rasters[0] + pRaster.aExtent_rasters[2]) / 2
dLatitude_focus_in = (pRaster.aExtent_rasters[1] + pRaster.aExtent_rasters[3]) / 2
pRaster.visualize_source_mesh(
    #sFilename_out=sFilename_mesh_png,
    dLongitude_focus_in=dLongitude_focus_in,
    dLatitude_focus_in=dLatitude_focus_in,
)
# Out:
# Widget(value='<iframe src="http://localhost:56670/index.html?ui=P_0x1d469fb90_0&reconnect=auto" class="pyvista…
# True

# %% [markdown]
# ## Run Remapping

# %%
pRaster.run_remap(iFlag_discrete_in=True)
# Out:
# 2026-01-20 14:43:48,656 - extract - INFO - Found 2 unique values in raster
# 2026-01-20 14:43:48,657 - extract - INFO - run_remap: Starting main feature processing loop...
# 2026-01-20 14:43:48,657 - extract - INFO - Preparing to process 1316 features (parallel threshold=10000)
# 2026-01-20 14:43:48,659 - extract - INFO - Feature count (1316) <= threshold (10000); using serial processing

# %%
pRaster.report_outputs()  # not implemented yet
# Out:
# 2026-01-20 14:44:50,633 - uraster - WARNING - No output file information available

# %% [markdown]
# ## Visualize Results

# %%
sColormap = "terrain"
pRaster.visualize_target_mesh(
    #sFilename_out=sFilename_variable_png,
    sColormap=sColormap,
    dLongitude_focus_in=dLongitude_focus_in,
    dLatitude_focus_in=dLatitude_focus_in,
)
# Out:
# Widget(value='<iframe src="http://localhost:56670/index.html?ui=P_0x1e3567e00_0&reconnect=auto" class="pyvista…
# True

# %% [markdown]
# ## Optional: Create Animation
#
# Uncomment and run the following cell to create an animation (may take some time).

# %%
pRaster.visualize_target_mesh(
    sFilename_out=sFilename_variable_animation,
    sColormap=sColormap,
    dLongitude_focus_in=dLongitude_focus_in,
    dLatitude_focus_in=dLatitude_focus_in,
    iFlag_create_animation=True,
    iAnimation_frames=360,  # 1° longitude per frame
    sAnimation_format="mp4",
)
# Out:
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (800, 600) to (800, 608) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# True

# %% [markdown]
# ## Cleanup

# %%
pRaster.cleanup()

print("done")
# Out:
# done
