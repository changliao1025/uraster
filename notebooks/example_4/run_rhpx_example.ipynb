# %% [markdown]
# # Example 4: Mesh Remapping
#
# This notebook demonstrates how to use uraster to remap raster data to an unstructured mesh.

# %%
import os
from uraster.classes.uraster import uraster
# Download input data using Pooch (downloads to system cache)
from uraster.utility import get_example_paths

print("Downloading example 4 input data...")
paths = get_example_paths(example_number=4, iUse_other_example_raster=3)
sFolder_input = paths['input']
print(f"Input data cached at: {sFolder_input}")

# Set up output directory relative to current working directory
sFolder_output = os.path.join("data", "example_4", "output")
os.makedirs(sFolder_output, exist_ok=True)
print(f"Output directory: {sFolder_output}")
# Out:
# Downloading file 'example_4.zip' from 'https://github.com/changliao1025/uraster_data/releases/download/v0.1.5/example_4.zip' to '/Users/liao313/Library/Caches/uraster'.
# Downloading example 4 input data...
# Downloading example 4 data...
# Source: https://github.com/changliao1025/uraster_data/releases/download/v0.1.5/example_4.zip
# 100%|█████████████████████████████████████| 67.9M/67.9M [00:00<00:00, 91.8GB/s]
# Unzipping contents of '/Users/liao313/Library/Caches/uraster/example_4.zip' to '/Users/liao313/Library/Caches/uraster/example_4.zip.unzip'
#   Organized files into input directory
# ✓ Downloaded and extracted: example_4.zip
#   Location: /Users/liao313/Library/Caches/uraster/example_4.zip.unzip/example_4
#   Files extracted: 5
# Input data cached at: /Users/liao313/Library/Caches/uraster/example_4.zip.unzip/example_4/input
# Output directory: data/example_4/output

# %%
# Convert absolute paths to relative paths
sFilename_source_mesh = os.path.join(
    sFolder_input, "rhealpix_China_res6.geojson"
)  # use the L10-100 test mesh
sFilename_raster = os.path.join(sFolder_input, "China_CH4_emission_2020.tif")

sFilename_target_mesh = os.path.join(sFolder_output, "uraster.geojson")
sFilename_mesh_png = os.path.join(sFolder_output, "mesh.jpg")
sFilename_raster_png = os.path.join(sFolder_output, "raster.png")
sFilename_variable_png = os.path.join(sFolder_output, "uraster.png")
sFilename_variable_animation = os.path.join(sFolder_output, "uraster_animation.mp4")

# %% [markdown]
# ## Configure and Run Remapping
#
# Set up the configuration and run the remapping process.

# %%
aConfig = dict()
aConfig["sFilename_source_mesh"] = (
    sFilename_source_mesh  # use the L10-100 test mesh
)
aFilename_source_raster = []
sFilename_source_raster_resample = sFilename_raster.replace(".tif", "_resample.tif")
# resample_raster(sFilename_raster, sFilename_source_raster_resample, 1.0, 1.0, sResampleAlg='average', dMissing_value_source =0)
aFilename_source_raster.append(sFilename_raster)  #
aConfig["aFilename_source_raster"] = aFilename_source_raster
aConfig["sFilename_target_mesh"] = sFilename_target_mesh

pRaster = uraster(aConfig)

# %%
pRaster.setup()
# Out:
# 2026-01-20 14:53:23,647 - uraster - INFO -   - Cleared 1 stale cache entries
# 2026-01-20 14:54:12,459 - uraster - INFO - Creating intermediate file with sequential integer field 'cellid'...
# 2026-01-20 14:54:51,336 - uraster - INFO - Added field 'cellid' to 62283 features
# 2026-01-20 14:54:51,337 - uraster - INFO - Successfully created intermediate file: /Users/liao313/Library/Caches/uraster/example_4.zip.unzip/example_4/input/rhealpix_China_res6_with_cellid.geojson
# 2026-01-20 14:54:51,337 - uraster - INFO - Updated source mesh path to: /Users/liao313/Library/Caches/uraster/example_4.zip.unzip/example_4/input/rhealpix_China_res6_with_cellid.geojson
# True

# %%
pRaster.report_inputs()
# Out:
# ============================================================
# Input Raster Information (1 file(s)):
# ============================================================
#
# [1] /Users/liao313/Library/Caches/uraster/example_4.zip.unzip/example_4/input/China_CH4_emission_2020_wgs84.tif
# Filename: /Users/liao313/Library/Caches/uraster/example_4.zip.unzip/example_4/input/China_CH4_emission_2020_wgs84.tif
# Width: 879
# Height: 430
# Band Count: 1
# Data Type: Float32
# NoData Value: None
# CRS: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Spatial Reference WKT: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Affine Transform: (57.49032405430756, 0.10594223224564564, 0.0, 56.79463547802224, 0.0, -0.10594223224564564)
# Extent: (57.49032405430756, 11.239475612394621, 150.61354619823007, 56.79463547802224)
# WGS84 Extent: (57.49032405430756, 11.239475612394621, 150.61354619823007, 56.79463547802224)
#
# ============================================================
# Mesh Topology Information:
# ============================================================
# Number of mesh cells: 62282
# Cell longitude range: 73.518 to 134.845
# Cell latitude range: 18.192 to 53.569
# Maximum vertices per cell: 121
# Total unique vertices: 3759005
# Connectivity matrix shape: (62282, 121)
#
# Cell Area Statistics:
#   Min area: 159648403.201286
#   Max area: 160831073.785560
#   Mean area: 160300179.450840
#   Area range ratio: 1.01x
# ============================================================

# %% [markdown]
# ## Visualize Source Mesh

# %%
# visualize source mesh at the Wuhan City area
dLongitude_focus_in = (pRaster.aExtent_rasters[0] + pRaster.aExtent_rasters[2]) / 2
dLatitude_focus_in = (pRaster.aExtent_rasters[1] + pRaster.aExtent_rasters[3]) / 2
pRaster.visualize_source_mesh(
    #sFilename_out=sFilename_mesh_png,
    dLongitude_focus_in=dLongitude_focus_in,
    dLatitude_focus_in=dLatitude_focus_in,
)
# Out:
# Widget(value='<iframe src="http://localhost:57097/index.html?ui=P_0x1d5b70620_0&reconnect=auto" class="pyvista…
# True

# %% [markdown]
# ## Run Remapping

# %%
pRaster.run_remap(iFlag_weighted_average_in=False)
# Out:
# 2026-01-20 14:56:55,191 - extract - INFO - run_remap: Starting main feature processing loop...
# 2026-01-20 14:56:55,192 - extract - INFO - Preparing to process 62282 features (parallel threshold=10000)
# 2026-01-20 14:56:55,223 - extract - INFO - Feature count (62282) > threshold (10000); using multiprocessing with 20 workers

# %%
pRaster.report_outputs()
# Out:
# 2026-01-20 14:57:33,211 - uraster - WARNING - No output file information available

# %% [markdown]
# ## Visualize Results

# %%
# Optional visualization and animation (disabled by default in this script)
sColormap = "terrain"
pRaster.visualize_target_mesh(
    #sFilename_out=sFilename_variable_png,
    sColormap=sColormap,
    dLongitude_focus_in=dLongitude_focus_in,
    dLatitude_focus_in=dLatitude_focus_in,
)
# Out:
# Widget(value='<iframe src="http://localhost:57097/index.html?ui=P_0x1e5711c40_0&reconnect=auto" class="pyvista…
# True

# %% [markdown]
# ## Cleanup

# %%
pRaster.cleanup()

print("done")
# Out:
# done
